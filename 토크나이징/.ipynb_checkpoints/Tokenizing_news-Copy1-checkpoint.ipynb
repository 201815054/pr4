# %%
import tensorflow as tf
import re
import pandas
import numpy
import json
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
# from tensorflow.python.keras.preprocessing.sequence import pad_sequences
# from tensorflow.python.keras.preprocessing.text import Tokenizer

# %%
# 전처리 
def preprocessing(news, remove_stopwords = False):
    #불용어 제거는 선택이 가능하도록
    
    # HTML 태그 제거
    news_text = BeautifulSoup(news, "html5lib").get_text()
    
    # 영어가 아닌 특수문자를 공백(" ")으로 바꾸기
    news_text = re.sub("[^a-zA-Z]"," ", news_text)
    
    # 대문자를 소문자로 바꾸고 공백 단위로 텍스트를 나누어 리스트화
    words = news_text.lower().split()
    
    # 한글자 없애기
    words = [w for w in words if len(w)>1]
    
    if remove_stopwords:
        # 불용어 제거
        
        # 영어 불용어 사전 불러오기
        stops = set(stopwords.words("english"))
        # 불용어가 아닌 단어로 이뤄진 새로운 리스트 생성
        words = [w for w in words if not w in stops]
        # 단어 리스트를 하나의 글로 합성
        clean_news = ' '.join(words)
        
    else: # 불용어 제거 옵션이 안 걸렸을시
        clean_news = ' '.join(words)
        
    return clean_news

# %%
def tokenizing(docs):
# 단어로 나눠서 리스트에 담기 
    clean_list = docs.split()
    
    # 공백더하기 
    clean_list = clean_list.append(' ')

# %%
# csv파일 불러오기 
news = pd.read_csv('../investing_crawl/world-news/news_world-news_00001.csv',index_col=0).dropna()
news
# Out:
#          company                                               date  \
# 0     By Reuters  <span>2 minutes ago (Apr 17, 2022 09:25PM ET)<...
# 1     By Reuters  <span>9 minutes ago (Apr 17, 2022 09:18PM ET)<...
# 2     By Reuters  <span>37 minutes ago (Apr 17, 2022 08:50PM ET)...
# 3     By Reuters  <span>1 hour ago (Apr 17, 2022 08:21PM ET)</span>
# 4     By Reuters  <span>1 hour ago (Apr 17, 2022 08:05PM ET)</span>
# ...          ...                                                ...
# 1713  By Reuters               <span>Jan 25, 2022 02:06AM ET</span>
# 1714  By Reuters               <span>Jan 25, 2022 12:42AM ET</span>
# 1715  By Reuters               <span>Jan 25, 2022 12:27AM ET</span>
# 1716  By Reuters               <span>Jan 24, 2022 11:05PM ET</span>
# 1717  By Reuters               <span>Jan 24, 2022 10:30PM ET</span>
#
#                                                   title  \
# 0     U.S. envoy in Seoul for talks over North Korea...
# 1     Ukrainians defy Russian surrender demand in Ma...
# 2     Police hunt for Pittsburgh party shooters who ...
# 3     Ukraine completes questionnaire for EU members...
# 4     Brazil arrests 'Colorido,' PCC drug gang's No....
# ...                                                 ...
# 1713  U.S. orders departure of Ukraine embassy staff...
# 1714  Burkina Faso army deposes president in West Af...
# 1715  NASA's new space telescope reaches destination...
# 1716  Tennis-'Where is Peng Shuai?' shirts welcome a...
# 1717  New York City Mayor Adams unveils plan to end ...
#
#                                                 content
# 0     By Josh Smith\nSEOUL (Reuters) - The U.S. envo...
# 1     By Oleksandr Kozhukhar and Alessandra Prentice...
# 2     (Reuters) - Police were searching for the shoo...
# 3     (Reuters) - Ukraine has completed a questionna...
# 4     RIO DE JANEIRO (Reuters) - Brazil's justice mi...
# ...                                                 ...
# 1713  By David Shepardson and Costas Pitas\nWASHINGT...
# 1714  By Thiam Ndiaga\nOUAGADOUGOU (Reuters) - Burki...
# 1715  By Steve Gorman\n(Reuters) -NASA's James Webb ...
# 1716  By Sudipto Ganguly\nMELBOURNE (Reuters) - Fans...
# 1717  By Barbara Goldberg and Julia Harte\nNEW YORK ...
#
# [1718 rows x 4 columns]

# %%
# 함수 적용  
clean_news = []
for text in news['title']:
    clean_news.append(preprocessing(text, remove_stopwords = True))
clean_news
# Out:
# ['envoy seoul talks north korea missile nuclear tensions',
#  'ukrainians defy russian surrender demand mariupol easter war',
#  'police hunt pittsburgh party shooters killed injured several',
#  'ukraine completes questionnaire eu membership official',
#  'brazil arrests colorido pcc drug gang leader',
#  'three people injured riots sweden',
#  'dozens still missing south africa floods death toll rises',
#  'state securities regulators order virtual casino firm stop selling nfts',
#  'shelling kills injures scores kharkiv past four days zelenskiy',
#  'ukraine russia need know right',
#  'jerusalem violence puts strain israel coalition government',
#  'archbishop canterbury condemns britain rwanda asylum plan',
#  'turkey erdogan condemns israeli intervention al aqsa mosque',
#  'death toll south african floods provincial premier',
#  'ukrainian foreign minister says situation mariupol may red line talks',
#  'french far left gives voting instructions internal consultations',
#  'french prosecutor studying eu anti fraud agency report le pen',
#  'easter war pope implicitly criticises russia ukraine',
#  'ukrainian prime minister says forces mariupol surrendered abc',
#  'luhansk region governor says shelling kills two injures four eastern town zolote',
#  'russia calls increased nato military activity arctic worrying warns unintended incidents tass',
#  'thai government says ramadan bombings derail peace talks rebels',
#  'myanmar junta says prisoners freed holiday amnesty',
#  'pakistan says cross border attacks afghanistan increased',
#  'indian police arrest communal clashes new delhi',
#  'family black man killed michigan police demands criminal charges',
#  'korea kim observes missile test boost nuclear capabilities',
#  'russia sets gmt deadline ukraine troops mariupol surrender',
#  'australia says would keep security ties solomons despite china pact',
#  'russia says forces clear mariupol strike kyiv suburb',
#  'pope condemns cruelty ukraine war easter vigil service',
#  'uk johnson leave home woes behind visit india',
#  'arrests migrants mexico border march rivaling record highs',
#  'clashes erupt indian capital hindu procession',
#  'russian navy head meets crew sunken missile cruiser defence ministry',
#  'south africa braces flooding rains restart east',
#  'opponents french far right protest election campaign enters final week',
#  'spanish village changes name ukraine show solidarity',
#  'chinese astronauts land earth china longest crewed space mission',
#  'six bodies retrieved migrants presumed dead boat shipwreck libya iom',
#  'french police fire tear gas anti far right protesters march paris',
#  'taliban authorities summon pakistani envoy protest military strikes',
#  'biden host summit asean leaders washington may white house',
#  'ukrainians brave russian mined cemetery mourn dead',
#  'moscow bars entry russia uk johnson truss wallace',
#  'pakistan new ruling alliance takes control parliament new speaker',
#  'south african flood victims search bodies lost loved ones',
#  'ukraine richest man vows rebuild besieged mariupol',
#  'kyiv mayor says killed several wounded missile strikes',
#  'thai rebels excluded talks take responsibility ramadan bombings',
#  'ukraine working turkey understands parallel ties russia ukrainian diplomat',
#  'taiwan says china threats increase support island',
#  'palestinians clash israeli police jerusalem holy site injured',
#  'pro russia serbs protest belgrade support russia nato',
#  'ukraine zelenskiy ukrainian troops died war',
#  'russian crowd mourns black sea flagship sinking',
#  'five people share reward tips new york subway shooting suspect',
#  'ukraine says fighting rages mariupol blasts rattle kyiv',
#  'united states urges restraint jerusalem violence',
#  'top officials discuss migration panama next week',
#  'sudan burhan gestures towards steps ease tensions',
#  'riots erupt sweden orebro ahead right wing extremist demonstration',
#  'wife putin ally held ukraine accuses kyiv authorities beating husband',
#  'russia warns stop arming ukraine washington post',
#  'belarus bans eu registered trucks entering country',
#  'zelenskiy asked biden designate russia state sponsor terrorism washington post',
#  'grants temporary deportation relief immigrants cameroon',
#  'big loss russia sinking moskva missile cruiser',
#  'analysis jerusalem clashes raise fears wider conflict',
#  'fortress city ukrainians cling steel plant mariupol',
#  'ukraine says russia used long range bombers mariupol first time war',
#  'recaptured ukrainian village left wrecked tanks bodies questions',
#  'paris suburb feels little love either presidential candidate',
#  'russian warship sinks ukraine says missile responsible',
#  'behind enemy lines ukrainian woman survives chickens',
#  'new york subway shooting suspect remain jail undergo psychiatric exam',
#  'preps new effort crack russian sanctions evasion',
#  'family black man killed michigan police demands criminal charges',
#  'capitol rioter said followed trump orders found guilty',
#  'cannot take lightly threat russia could use nuclear weapons cia chief',
#  'russia warns nuclear hypersonic deployment sweden finland join nato',
#  'state department says defense alliance expansion would promote european stability',
#  'stranded seafarers escape ukraine others trapped ilo sources',
#  'biden says deciding sending envoy ukraine',
#  'vp harris condemns attacks israel call president',
#  'pakistan military dismisses khan theory conspired oust pm',
#  'trump says probably return twitter musk reinstated account',
#  'white house launches diversity action plan government',
#  'six lawmakers arrive taiwan unannounced trip',
#  'thousands sri lankans celebrate new year anti government protest site',
#  'shanghai cases hit record xi reiterates urgency covid curbs',
#  'new york subway shooting suspect arrested mass transit violence charge',
#  'south korea official signals leaflet balloons might float north',
#  'biden remark yet commit genocide probe russia',
#  'kremlin says biden genocide comments wrong unacceptable',
#  'troops burn villages myanmar heartland seek crush resistance',
#  'gives ukraine million military aid adds heavy weapons',
#  'state securities regulators order virtual casino firm stop selling nfts',
#  'ukraine warns new russian offensives amid push mariupol',
#  'macron says le pen showing authoritarian streak journalist ban',
#  'sri lanka pm offers protesters talks opposition eyes confidence vote',
#  'sets new mideast naval task force amid strained gulf ties',
#  'russia says ukrainian marines surrender mariupol',
#  'ukraine zelenskiy biden discuss defensive aid sanctions',
#  'massachusetts city agrees justice department reform police',
#  'european rights experts say russia committed war crimes ukraine',
#  'nadia murad launches guidance collecting rape war evidence',
#  'zelenskiy accuses russia using phosphorous bombs terror tactics',
#  'mariupol defenders surrender russia prepares next attack putin ally captured',
#  'ukrainians want russians removed pope good friday procession',
#  'iran guards commander says death us leaders would avenge soleimani killing',
#  'small tent camp sri lankan city becomes focus national protests',
#  'oklahoma governor signs near total abortion ban threatens prison providers',
#  'chechen chief kadyrov says ukrainian marines surrender mariupol',
#  'golf major win cements scheffler world best player',
#  'manhunt way gunman nyc subway shooting injured least',
#  'nba brooklyn nets coach nash says subway attack hits close home',
#  'trucker protests expand mexico border lengthy wait times',
#  'gilbert gottfried boundary pushing comedian dead',
#  'athletics boston boost police presence subways ahead marathon',
#  'new york subway shooting new test mayor promise police gun violence',
#  'ukraine zelenskiy mocks putin saying war going plan',
#  'judge declines jail two men accused impersonating federal agents',
#  'crypto researcher sentenced five years helping north korea evade sanctions',
#  'mexican cartels swap arms cocaine fueling colombia violence',
#  'biden stands genocide remark sure seems way',
#  'new york lieutenant governor resigns bribery charges',
#  'new york lieutenant governor resigns bribery charges governor',
#  'french forensic experts bucha help ukraine investigate possible war crimes',
#  'putin top ally ukraine arrested say authorities',
#  'judge declines detain two men accused posing federal agents',
#  'screening anxiety begin age panel says',
#  'gunman shoots new york subway car officials',
#  'cannot confirm use chemical weapons ukraine blinken says',
#  'south dakota lawmakers vote impeach attorney general',
#  'factbox despite recent uptick new york city crime past decades',
#  'able confirm reports use chemical weapons ukraine blinken',
#  'ny lieutenant governor benjamin pleads guilty bribery related charges',
#  'johnson biden discussed boosting support ukraine downing street',
#  'abandoned east ukraine cats dogs look new homes russia',
#  'mayor ukraine bucha says bodies found far',
#  'russian court dismisses appeal jailed former marine trevor reed',
#  'russia launch lunar probe deepen space links belarus putin',
#  'aircraft carrier deploys korean peninsula amid tensions north',
#  'chemical weapons illegal',
#  'shanghai eases covid curbs even factory halts widen',
#  'uk says options table russia uses chemical weapons ukraine',
#  'drugs running surgeries cancelled sri lanka health system buckles',
#  'prosecutor drop charges texas woman abortion',
#  'ukraine says tens thousands killed mariupol accuses russia abuses',
#  'khan lawmakers quit en masse pakistan parliament elects sharif pm',
#  'teens recruited drive migrants mexican border',
#  'monitoring rise rights abuses india blinken says',
#  'ukraine girds russian offensive east',
#  'two men accused impersonating federal agents seek release jail',
#  'ex police officer found guilty second capitol riot jury trial',
#  'exclusive brazil invites eu first time observe national election',
#  'macron le pen battle cost living heated runoff campaign',
#  'russian regions bordering ukraine step security',
#  'small french village le pen threatens macron election',
#  'russia says west helping ukraine prepare fake allegations war crimes',
#  'judge delays trial men accused assaulting capitol police amid plea talks',
#  'vatican mulling jerusalem meeting pope russian patriarch sources',
#  'army experience drives ukraine vereshchuk secure prisoner release',
#  'italy unions protest projected decline school spending',
#  'australian election campaign kicks opposition ahead polls',
#  'ukraine conflict hurts russian science west pulls funding',
#  'analysis politics substance seen guiding iran terror listing',
#  'korea celebrates years kim jong un top party leader',
#  'russian ex journalist trial treason fight end',
#  'hong kong police arrest veteran journalist alleged sedition',
#  'mexican president wins backing leadership vote sought',
#  'exclusive senior eu officials targeted israeli spyware sources',
#  'explainer united states resettle ukrainian refugees march',
#  'political change pakistan shehbaz sharif seeks become pm',
#  'battle looms ukraine east austrian leader meet putin',
#  'france traditional parties bloodied vote far right hard left',
#  'israel west bank edge bloodshed',
#  'shanghai residents question human cost china covid quarantines',
#  'prosecutor drop charges texas woman abortion',
#  'explainer macron le pen matters france eu west',
#  'supply ukraine weapons needs russia',
#  'syria gas attack victims awaiting justice say impunity fuels war crimes',
#  'iran mps set conditions reviving nuclear deal amid stalled talks',
#  'ukraine conflict hurts russian science west pulls funding',
#  'economy climate trust centre australia may election',
#  'china labels concerns covid regulations groundless accusations',
#  'zelenskiy braces hard battle uk johnson visits aid',
#  'pakistan prime minister imran khan ousted confidence vote parliament',
#  'protesters gather outside texas jail reported abortion arrest',
#  'sharif frontrunner next pakistani pm seen administrator',
#  'space station first private astronaut team welcomed aboard orbiting platform',
#  'imran khan cricket star turned pakistan premier ousted',
#  'israeli forces kill palestinian militant west bank clash',
#  'france macron makes last minute appeal voters le pen reaches time high poll',
#  'iran imposes sanctions americans nuclear talks stall',
#  'residents return charred changed bucha ukraine',
#  'idaho top court temporarily blocks six week abortion ban',
#  'british diver rescued malaysia says son died sea',
#  'judge weighs detention two men accused impersonating security agents',
#  'ukraine allies blame russia strike station killed',
#  'former usc water polo coach convicted college admissions scandal trial',
#  'trump organization wins suit new york city golf course contract',
#  'russians bury dead soldiers kremlin admits major losses ukraine',
#  'private astronaut team lifts landmark launch space station',
#  'believes russia used short range ballistic missile railway station strike official',
#  'ukraine says dozens killed missile strike railway station used evacuees',
#  'condemning bucha cruelty eu offers speedy start ukraine membership',
#  'pakistan pm khan says recognise opposition attempt oust',
#  'leading proud boys member pleads guilty capitol riot charges',
#  'ukrainian villagers count dead weeks confined school basement',
#  'macron makes last minute appeal dispirited left le pen surges',
#  'ukraine russia need know right',
#  'elon musk arrival stirs fears among twitter employees',
#  'third puerto rico remains dark second day',
#  'china uses ai software improve surveillance capabilities',
#  'alabama passes bill making transgender healthcare felony',
#  'senate confirms jackson first black woman supreme court',
#  'analysis china balancing act ukraine offers washington subtle win',
#  'yemen president cedes powers council saudi arabia pushes end war',
#  'massive power outage leaves third puerto rico dark',
#  'russia laments significant losses ukraine braces major offensive',
#  'biden move lifting covid curbs migrants border democrats defensive',
#  'denver appeal million verdict case police protests',
#  'suspends russia human rights body moscow quits',
#  'biden jackson deliver remarks jackson senate confirmation supreme court',
#  'factbox historic firsts diversifying supreme court',
#  'pakistan court rules imran khan bringing ouster closer',
#  'death defiance bucha neighbourhood held russian troops',
#  'sri lanka calls billion debt restructure crisis rages',
#  'nato allies pledge arms ukraine',
#  'former usc water polo coach admissions scandal took bribes lawyer argues',
#  'boy scouts defeat girl scouts trademark lawsuit co ed scouting',
#  'un general assembly suspends russia human rights body',
#  'french court upholds million euro fine google opaque ad rules',
#  'braving mined streets reach czech village two mariupol mums chart new life',
#  'smuggled sketches offer glimpses harsh myanmar prison',
#  'korea president elect vows strong deterrence amid korea nuclear test signs',
#  'factional chaos missteps brought yemen president hadi',
#  'feet tied bullet head killing ukraine bucha',
#  'pentagon says ukraine absolutely win war',
#  'jury still deliberating michigan governor kidnap trial',
#  'road rage shootings soared pandemic gun control group says',
#  'kentucky governor beshear vetoes transgender sports ban',
#  'fda aims decide strain selection covid boosters june',
#  'fbi says disrupted russian hackers',
#  'man convicted sex trafficking extorting new york college students',
#  'russia bombards imposes sanctions ukraine urges decisive help',
#  'says china could face sanctions supports russia war ukraine',
#  'nato says russia regrouping try take ukraine donbas',
#  'parents ex marine jailed russia worried something terrible happened',
#  'leader campaign fund trump border wall plead guilty conspiracy tax charges',
#  'sri lanka president resign despite protests minister',
#  'roadside burial labourer shot head ukraine bucha',
#  'iran moves machines making centrifuge parts natanz un nuclear watchdog',
#  'school boards statehouses conservative moms liberty push grow influence',
#  'hong kong deputy chief says plans run city top job',
#  'stunning reversal protests leave sri lanka ruling dynasty teetering',
#  'batiste wins album honor zelenskiy makes appeal grammys',
#  'korea president elect wants nuclear bombers submarines return',
#  'iran nuclear chief says tehran given iaea documents outstanding issues',
#  'first private astronaut mission space station readies launch',
#  'provide additional million security assistance ukraine blinken',
#  'ukraine demands accountability russian war crimes west prepares sanctions',
#  'michigan governor kidnap plot jury ends nd day deliberations',
#  'pushes suspend russia human rights body',
#  'argentina wants china fully fund billion nuclear plant amid cash shortfall',
#  'kremlin says bucha monstrous forgery aimed smearing russia',
#  'fed bars six former bankers covid grant fraud',
#  'cities drive climate change provide solution un says',
#  'never severe emissions cuts avoid climate extremes report',
#  'conservative conference hungary hardline leader reflects republican divide',
#  'turkey ready attempt fixing strained ties',
#  'ukrainian street corpse hands bound bullet wound head',
#  'special report france closes mosques powers critics say use secretive evidence',
#  'biden urges putin war crimes trial bucha killings',
#  'cdc announces revamp plans hires outside official review',
#  'new york mayor adams launches florida ads denouncing law lbgtq talk schools',
#  'west pledges punish russia civilian killings bucha',
#  'russia likely shift tactics send thousands soldiers eastern ukraine says',
#  'police arrest suspect california shooting left six dead wounded',
#  'hundreds ukrainians shelter mexico wait cross border',
#  'first private astronaut mission space station readies launch',
#  'obvious russian forces responsible atrocities ukraine bucha pentagon says',
#  'build case russia war crimes icc venue sullivan',
#  'supporting prosecutors collecting evidence ukraine atrocities spokesperson',
#  'explainer could russia putin prosecuted war crimes ukraine',
#  'ex marine reed ends hunger strike russian prison agencies',
#  'concerned reports american trevor reed health deteriorating',
#  'jury selection begins man facing death florida mass school shooting',
#  'orban victory puts hungary collision course eu',
#  'putin faces nato arctic ukraine invasion',
#  'hong kong leader carrie lam says seek second term',
#  'batiste wins album honor zelenskiy makes appeal grammys',
#  'jury weigh fate men charged michigan governor kidnapping plot',
#  'georgian foreign minister resigns become ambassador tass',
#  'iran blames halt vienna nuclear talks',
#  'conscripts sent fight pro russia donbas get little training old rifles poor supplies sources',
#  'fresh turmoil pakistan pm khan dodges ouster opposition vows fight',
#  'zelenskiy asks grammys audience support way',
#  'sacramento police say multiple shooters violence left six dead',
#  'serbia incumbent president vucic set win second term',
#  'orban scores crushing victory ukraine war solidifies support',
#  'explainer political upheaval pakistan means rest world',
#  'ukraine accuses russia civilian massacre moscow denies',
#  'ukrainian mayor shows dead bodies amid battle scarred city bucha',
#  'golf woods says make game time decision playing masters',
#  'explainer could russia putin prosecuted war crimes ukraine',
#  'russia denies killing civilians ukraine bucha',
#  'pope struggles leg pain malta defends migrants',
#  'human rights watch accuses russian forces apparent war crimes ukraine',
#  'protesters sri lanka defy curfew police fire tear gas students',
#  'taliban bans drug cultivation including lucrative opium',
#  'eu accuses russian troops committing atrocities ukrainian town bucha',
#  'shanghai asks entire city self test covid frustration grows',
#  'ukraine claims control kyiv region russia looks east',
#  'macron warns brexit like election upset mass campaign rally',
#  'ukrainian president says retreating russian troops leaving mines',
#  'russian retreat leaves trail slain civilians town near kyiv',
#  'ukrainian photographer reuters contributor maksim levin killed covering war',
#  'britain could build seven nuclear power stations minister',
#  'la court rules state corporate diversity law unconstitutional',
#  'pope implicitly criticises putin invasion considers kyiv trip',
#  'mariupol residents flee russian forces hunt ukrainian fighters',
#  'truce offers glimmer hope yemenis battered seven year war',
#  'sri lanka imposes curfew president declares state emergency',
#  'pakistan pm accuses united states backing move oust',
#  'pope uses elevator board plane taking malta',
#  'nepal prime minister visits india meets modi deepen ties',
#  'shanghai separates covid positive children parents virus fight',
#  'russia trades accusations ukraine drifting black sea mines',
#  'germany looks buy israeli missile defence system',
#  'discusses opportunities taiwan participate meeting',
#  'china tells eu pursue ukraine peace way',
#  'work allies transfer soviet made tanks ukraine ny times',
#  'provide additional million security assistance ukraine',
#  'ukraine russia need know right',
#  'amazon union leader smalls went rapper unlikely voice protest',
#  'former goalkeeper solo arrested suspected dwi',
#  'end covid order blocking asylum seekers border mexico',
#  'bodies tanks mark path russia moves troops kyiv',
#  'jury handed case men charged michigan governor kidnapping plot',
#  'exclusive cancels icbm test due russia nuclear tensions',
#  'urged toughen protections women temporary work programs',
#  'two detainees released afghanistan state dept',
#  'descent hell ukrainians reclaim shelled homes near kyiv',
#  'first missing murdered indigenous alert system created',
#  'bill legalize marijuana passes house faces dim prospects senate',
#  'issues fresh north korea sanctions recent missile launches',
#  'turkish ministry approve request transfer khashoggi case arabia',
#  'navy name ship late supreme court justice ruth bader ginsburg',
#  'sri lanka lifts curfew violent protests economic crisis',
#  'solomon islands allow chinese military base says pm office',
#  'korea may preparing new nuclear tests improve arsenal allies say',
#  'shanghai expands covid lockdown life hold city million',
#  'setback democrats new york judge throws new congressional map',
#  'envoy moscow says russia ties sunk mariana trench depths',
#  'issue gender neutral passports take steps combat anti transgender laws',
#  'hong kong govt strongly opposes uk us report city diminishing freedoms',
#  'europe russian gas jeopardy ukraine girds new attacks',
#  'migrants stuck mexico hopeful lift covid era expulsion policy border',
#  'trump son law kushner appears house jan committee',
#  'exclusive warned firms russia kaspersky software day invasion sources',
#  'fetuses discovered dc home anti abortion activists charged storming clinic',
#  'says small number outstanding issues iran nuclear talks',
#  'recognize results russian effort divide georgian territory state dept',
#  'state dept sees limited progress consular access detained americans',
#  'depression suicidal thoughts prevalent high school students pandemic study',
#  'louisiana republicans override governor veto enact new congressional map',
#  'explainer russia internet crackdown',
#  'russia jehovah witnesses caught extremist law',
#  'china restrict visas officials says foreign ministry',
#  'says china pressure taiwan threat democracies',
#  'russians abroad try get ukraine news relatives homeland',
#  'russia bombards kyiv outskirts regroups offensive east ukraine',
#  'press broader yemen truce unilateral moves',
#  'biden offers condolences israel bennett attacks',
#  'oklahoma arizona ban transgender students girls sports',
#  'alex jones found contempt court sandy hook lawsuit',
#  'chinese agent targeted dissidents united states prosecutors say',
#  'fbi investigating threats made connection whitmer kidnapping trial',
#  'white house wants india ambassador nominee receive expeditious vote senate',
#  'looking options sanctions russia ukraine white house',
#  'white house expects influx people border covid era policy lifted',
#  'majority americans back sending troops nato ukraine crisis reuters ipsos poll',
#  'separatist leader says left mariupol russia donetsk',
#  'biden says decision coming soon covid curbs border',
#  'maryland lawmakers pass measure expanding abortion access',
#  'prosecutors accuse alleged isis beatle brutal hostage taking',
#  'california task force votes limit eligibility slavery reparations',
#  'astronaut two russian cosmonauts return home iss',
#  'explainer peace talks ukraine russia red lines unchanged',
#  'israeli forces high alert deadly palestinian shooting attack',
#  'jordan israel leaders urge calm historic meeting following spike violence',
#  'uk judges resign hong kong court china crackdown dissent',
#  'exclusive hackers crippled viasat modems ukraine still active company official',
#  'thousands australians flee homes floods inundate towns',
#  'cubans split liberal family code referendum nears',
#  'hong kong leader says city brain drain unarguable',
#  'china dji rejects claims data leaks russia ukrainian military positions',
#  'korea says korea staged largest icbm fakery recover failed test',
#  'villages near kyiv ukraine kept russia army bay',
#  'sends senior national security official india discuss ukraine',
#  'preps possible spike border crossings officials mull lifting covid curbs',
#  'thousands civilians mariupol may died past month un tells reuters',
#  'saudi led coalition halt military operations yemen help negotiations spa',
#  'liaising ukrainian forces poland pentagon says',
#  'biden says see russia de escalates ukraine',
#  'russia pledges reduce attack kyiv warns threat',
#  'scholz biden allies agree keep pushing russian ceasefire german govt',
#  'abramovich appears ukraine russia talks istanbul',
#  'ukraine offers neutrality exchange nato style security guarantees russia talks',
#  'oil iran ukraine top agenda blinken meets uae leader',
#  'brazil bolsonaro super well overnight stay hospital',
#  'uk police issue first fines downing street lockdown parties',
#  'war means tough choices ukraine vast child protection system',
#  'singapore court rejects malaysian appeal high profile execution case',
#  'shanghai tightens covid lockdown second day curbs',
#  'heavy rains australia trigger fresh round flood evacuations',
#  'peru castillo survives impeachment vote congress',
#  'korea kim calls ramping ideological campaigns amid worst difficulties',
#  'supreme court takes copyright battle warhol prince paintings',
#  'israel arab partners close ranks iran urge palestinian talks',
#  'ukraine sets ceasefire goal russia talks says putin ready end war',
#  'kremlin spokesman russia would use nuclear weapons case threat existence state',
#  'ukraine zelenskiy says tougher russian sanctions needed quickly',
#  'canada indigenous ask pope residential schools records',
#  'gunmen kill cockfight troubled western mexican state',
#  'kremlin says biden remark end putin alarming',
#  'volcanologists seek answers island portugal azores keeps shaking',
#  'eu seeks end golden passport schemes halt sales visas russians',
#  'taliban bars government employees without beards work',
#  'european justice agency backs team probing alleged war crimes ukraine',
#  'kremlin says russia ukraine talks could start turkey tuesday',
#  'analysts investigate possibility korea missile test deception',
#  'stars bring color glitter skin oscars red carpet',
#  'evacuation order issued avalanche stricken anchorage suburb',
#  'china dji rejects claim russian military uses drones ukraine',
#  'two arab gunmen kill two police officers israel shot dead israeli officials',
#  'ukraine says russian forces near chernobyl could pose new radiation threat',
#  'israeli arab summit convenes blinken seeks reassure allies iran',
#  'kim says korea keep developing formidable striking capabilities kcna',
#  'ukraine willing neutral says russia wants split nation',
#  'russia azerbaijan trade barbs nagorno karabakh',
#  'el salvador invokes emergency powers surge homicides',
#  'canada indigenous peoples seek papal apology vatican residential schools',
#  'ukrainian civilian death toll reaches',
#  'analysis impermanence nation canada growing reliance temporary residents meet labor needs',
#  'envoy confident iran nuclear deal imminent',
#  'china recovers second black box crashed passenger jet',
#  'uk prince william says wants serve caribbean criticism',
#  'afghanistan taliban ban women flying without male chaperone sources',
#  'russia hits ukraine lviv cruise missiles defence ministry says',
#  'philippines alert volcano near capital spews plumes',
#  'uk prince william hints backing caribbean nations become republics',
#  'explainer black boxes crashed chinese jet handled',
#  'rockets hit western ukraine biden visits poland decries putin',
#  'multiple rockets hit lviv city western ukraine',
#  'china confirms board china eastern plane died crash',
#  'eu borrell says nuclear agreement iran close',
#  'analysts say images monster north korean icbm may earlier launch',
#  'tears uncertainty locals leave earthquake hit azores island',
#  'iraq parliament fails elect new state president lack quorum',
#  'philippines evacuates residents small volcano spews mile high plume',
#  'russia conducts military drills isles disputed japan media',
#  'nothing grief says father plane crash victim',
#  'great concern china solomon islands deal australia pm',
#  'chinese minister seeks normal india ties delhi says ease border tension first',
#  'korea says tested new icbm prepared long confrontation',
#  'russia reframes war goals ukrainians advance near kyiv',
#  'korea says new icbm curb dangerous washington seeks new sanctions',
#  'poland biden visits troops nato eastern flank',
#  'republican vetoes transgender sports bans mark rare split culture wars',
#  'analysis bogged ukraine russia moves war goalposts',
#  'eu leaders present united front row fix energy crunch',
#  'supreme court backs navy fight anti vaccine seals',
#  'japanese south korean officials condemn north korea missile launch state dept',
#  'birds laying eggs earlier climate change shifts springs',
#  'urges china russia send strong message north korea missile launch',
#  'sees russia focusing eastern ukraine senior defense official says',
#  'jill biden poland agata kornhauser duda partner ukraine aid',
#  'ukraine russia need know right',
#  'pope leads global prayer peace russia ukraine',
#  'lost yemenis face eighth year struggle war grinds',
#  'presidents meet ukraine refugees want fighting end',
#  'nato contingency planning possible russian attack white house',
#  'analysis largest test yet korea icbm programme hits new heights',
#  'five things watch sunday academy awards ceremony',
#  'soccer world cup woes continue italy european champions',
#  'ukraine war reverberates taiwan frontline democracy',
#  'donald trump sues hillary clinton russian collusion allegations',
#  'beijing autoshow postponed due covid surge china sources',
#  'ambassador urges mexico side ukraine russia conflict',
#  'west assails russian barbarism ukrainians shelter bombardment',
#  'russia burden china ukraine invasion pentagon official',
#  'arizona oklahoma legislatures pass transgender sports bans',
#  'russia emerge ukraine conflict weaker senior pentagon official says',
#  'west gives support ukraine raises stakes russia',
#  'imposes sanctions targeting north korea missile program',
#  'factbox north korea new hwasong monster missile',
#  'vote revoke favored trade status russia delayed senate',
#  'house panel probing capitol riot vote contempt charge two trump associates',
#  'fearing bombs war kharkiv families spend month underground',
#  'welcome ukrainians fleeing war amid broader aid effort',
#  'unveils rule speed asylum processing deportations border',
#  'macron underscores leader credentials nato map',
#  'lawsuit seeks block insurrectionist marjorie taylor greene reelection bid',
#  'biden says would lucky trump ran',
#  'korea defense chiefs agree need firm responses launch pentagon',
#  'sanctions see russians panic buy anti depressants sleeping pills data',
#  'nyc mayor adams lifts vaccine mandate pro athletes performers',
#  'making plans case russia uses chemical nuclear weapons',
#  'analysis biden faces worsening north korea threat fewer options',
#  'erdogan says ukraine russia remain odds territory',
#  'ukraine uses facial recognition identify dead russian soldiers minister says',
#  'announces new russia sanctions ukraine invasion',
#  'refugees plead protection ukraine western leaders meet',
#  'month war communicator chief zelenskiy strives keep eyes ukraine',
#  'wikileaks assange gets married uk high security jail',
#  'myanmar special command authorised lethal attacks civilians report',
#  'taliban orders girls high schools remain closed leaving students tears',
#  'south korea disgraced ex president park returns home prison',
#  'ukraine russia need know right',
#  'says instances attacks health care since ukraine war started',
#  'mackenzie scott donates record million planned parenthood',
#  'uk provide missiles ukraine new support',
#  'biden arrives europe ukraine war summits nato bolster eastern flank',
#  'madeleine albright remembered trailblazer world stage',
#  'biden lands europe middle dispute russian energy sanctions',
#  'sets red lines china helping russia dodge sanctions',
#  'russia military hit high ranking losses ukraine',
#  'basketball player detained russia good condition state dept',
#  'iran foreign minister says closer ever nuclear deal reuters',
#  'russia putin gets chinese backing stay',
#  'poland expels russian diplomats official says',
#  'china plane crash site relatives wait grim vigil',
#  'british royals jamaica visit stirs demands slavery reparations',
#  'taiwan weighs extending compulsory military service beyond months',
#  'tornado rips new orleans destroying homes one dead',
#  'russia ambassador indonesia says putin plans attend summit',
#  'russian strikes turning mariupol ashes west plans sanctions',
#  'counter china influence names envoy lead pacific island talks',
#  'utah governor vetoes bill banning trans girls school sports',
#  'azores watch large quake eruption island keeps shaking',
#  'baseball new york mayor says rushed vaccine rules opening day horizon',
#  'florida governor declares weyant winner transgender athlete',
#  'russia trades barbs uk chemical weapons ukraine',
#  'russian court finds jailed kremlin critic navalny guilty fraud',
#  'diplomatic tit tat ukraine escalates united nations',
#  'arab attacker kills four israel fatally shot police say',
#  'russian news website blames hack report nearly army deaths ukraine',
#  'prosecutors rule bringing charges proud boys case',
#  'ukraine leader says nothing left mariupol kherson also facing humanitarian disaster',
#  'europe struggles meet mounting needs ukraine fleeing millions',
#  'parents reuters photographer killed afghanistan start legal action taliban',
#  'ukraine president zelenskiy insists meeting putin',
#  'blinken says myanmar army committed genocide widespread systematic attacks rohingya',
#  'kremlin dismisses warning potential russian cyber attacks',
#  'wwii holocaust survivor killed ukraine kharkiv',
#  'russia sentences kremlin critic navalny nine years prison court',
#  'biden says putin could use chemical biological weapons ukraine',
#  'japan protests russian halt world war two peace treaty talks',
#  'russian court finds kremlin critic navalny guilty fraud',
#  'ukraine rejects ultimatums conflict intensifies',
#  'chernobyl staff wanted leave nuclear watchdog says',
#  'tornadoes rip north texas damaging homes businesses',
#  'miami beach declares curfew spate gun violence',
#  'biden says putin weighing use chemical weapons ukraine',
#  'moscow ties close rupture biden war criminal remarks russia says',
#  'uk aid worker asks left iran six years',
#  'russia may stop ukraine nato looks weakest link',
#  'eu allies coordinate china nato meetings week',
#  'british police begin interviews lockdown downing street party investigation',
#  'un expert urges north korea dismantle political prison camps',
#  'ukrainian refugees poland queue work permits border crossings ebb',
#  'german resort rift russian oligarch resonates across country',
#  'flow ukrainian refugees testing limits central europe capacity',
#  'biden travel poland discuss ukraine crisis duda',
#  'biden administration rules myanmar army committed genocide rohingya',
#  'fighting rages mariupol ukraine zelenskiy appeals help israel',
#  'wisconsin police officer accused using knee restraint year old girl',
#  'envoy decries disturbing accounts ukrainians deported russia',
#  'parents arms ontario school board move keep masks',
#  'car drives belgian carnival troupe kills six',
#  'ramos horta guterres early frontrunners east timor election',
#  'korea fires multiple rocket launcher south says',
#  'china right side history ukraine war foreign minister',
#  'syrian veterans ready ukraine fight commanders say',
#  'british royal couple starts caribbean tour dogged protest belize',
#  'korea yoon says move presidential office defence ministry',
#  'top ballet performers dance ukraine charity event',
#  'texas wildfires destroy homes small town dallas morning news',
#  'ukraine mariupol says russia forcefully deported thousands people',
#  'people wounded gunfire outside car show arkansas police',
#  'zelenskiy calls peace talks moscow urges swiss target oligarchs',
#  'suggested turkey transfer russian made missile system ukraine sources',
#  'judge rules kentucky clerk denied sex marriage licenses',
#  'russia ridicules idea cosmonauts wore yellow support ukraine',
#  'stuck mexico border anti war russians sweat futures ukrainians enter',
#  'ukrainian refugees find shelter solace polish theatre',
#  'pope rules baptised lay catholics including women lead vatican departments',
#  'meet ukrainian couples training war',
#  'east timor asia youngest nation votes president',
#  'dead buildings tower uncollected corpses mariupol front line ukraine war',
#  'new russian cosmonaut team welcomed aboard international space station',
#  'ukraine russia need know right',
#  'mexico migration institute suspends operations tapachula violent incident',
#  'xi says improper handling taiwan issues hit china ties',
#  'longest serving congressman alaska young dies',
#  'syria assad visits uae first trip arab state since war began',
#  'russia tightening noose mariupol biden tells china fuel assault',
#  'putin vows russia prevail ukraine glitch hinders tv',
#  'biden xi call warns china could face sanctions backs russia ukraine',
#  'residents ukraine mariupol fleeing foot says governor',
#  'nothing suggests putin intent altered russian invasion western official',
#  'nasa big new moon rocket begins rollout en route launch pad tests',
#  'chinese carrier sails taiwan strait hours biden xi call',
#  'russia canada twitter spat kindergarten level un letter post',
#  'australian watchdog sues facebook owner meta scam advertisements',
#  'russia advance ukraine stalls warns china aiding moscow',
#  'ex trump chief staff meadows probed carolina voter registration',
#  'russia pulls vote ukraine arm twisting claims',
#  'ukrainian refugees hope peace expected flee',
#  'blinken says war crimes committed ukraine experts working document attacks',
#  'putin warning traitors sends chilling message',
#  'texas man pleads guilty assaulting police capitol riot',
#  'biden xi speak warns china military aid ukraine war',
#  'zelenskiy urges germany tear wall dividing free unfree europe',
#  'quake japan kills two halts factories cuts power thousands homes',
#  'analysis gamble china ukraine raises tensions rival superpower',
#  'year atlanta spa shootings americans rally anti asian hate',
#  'green island turns red madagascans struggle long drought',
#  'two british iranians arrive britain ending iran prison ordeal',
#  'putin recognised war criminal ukrainian defence minister tells eu lawmakers',
#  'china rejects blinken accusation china acting line un charter',
#  'european leaders risky kyiv mission took even close family surprise',
#  'analysis korea missile programme even failures sign progress',
#  'japan spots four russian amphibious transports sailing far east',
#  'korea silent reported missile explosion pyongyang',
#  'biden calls putin war criminal russia says mission going plan',
#  'ukraine zelenskiy asks congress protect sky russia',
#  'quake hits japan fukushima coast leaving two dead reviving painful memories',
#  'security council vote friday russia move ukraine',
#  'weighs dropping iran irgc terrorism list source',
#  'justice department accuses china spying intimidating dissidents living',
#  'canada ditch pre arrival covid testing requirement travelers source',
#  'canada launches million fund tackle gun violence',
#  'world court orders russia halt military operations ukraine',
#  'iran defies western powers work near weapons grade uranium',
#  'bars ex spies becoming mercenaries following reuters series',
#  'explainer accepting ukrainian refugees',
#  'suspected korea missile explodes mid air launch near pyongyang',
#  'poland wants urgently buy reaper drones russia fears mount',
#  'putin warns russia pro western traitors scum',
#  'raises less third billion sought yemen avoid starvation',
#  'idaho senate halts healthcare bill targeting trans youth',
#  'factbox russia suggests sweden austria military model ukraine',
#  'nato vows help ukraine begins planning adapt new reality',
#  'hindu hardliners seek wider india ban hijab class court verdict',
#  'world court profoundly concerned russia use force ukraine presiding judge',
#  'pledges million new aid yemen blinken',
#  'analysis kremlin putin ponders war peace',
#  'california rapid shelter model gets people streets',
#  'putin says russia achieve goals ukraine bow west',
#  'maxwell says juror sought minutes fame prosecutors call trial fair',
#  'exclusive state tv protester tells russians open eyes ukraine war propaganda',
#  'nurse cares surrogate children kyiv war stops seeing',
#  'putin says keeping russia check west long term policy',
#  'russia tells kyiv must stall talks outside influence',
#  'biden grant temporary deportation relief afghans united states',
#  'zelenskiy calls congress russia sanctions defense aid',
#  'begins flying japanese non lethal military aid ukraine',
#  'taiwanese island drills underscore strategic importance vulnerability',
#  'russia says parts ukraine compromise deal close',
#  'russia lavrov says deals ukraine close agreed',
#  'korea courts disaster missile tests international airport',
#  'china says taiwan taking advantage ukraine island sends aid',
#  'suspect arrested homeless men shot washington new york',
#  'top polish politician calls peacekeeping mission ukraine',
#  'russia says written guarantees iran nuclear deal',
#  'biden assess ukraine conflict nato meeting next week',
#  'fox news cameraman ukrainian journalist killed ukraine',
#  'suspect arrested new york museum stabbing charged assault',
#  'gcc officials consider inviting yemen houthis consultations riyadh',
#  'abramovich flies moscow yachts seized caviar banned hit russia rich',
#  'prosecutors seek longer stricter jail term kremlin critic navalny',
#  'ukraine born businessman gets one year prison campaign finance case',
#  'western sanctions target russia',
#  'anti war protester studio disrupts live russian state tv news',
#  'russia bars entry biden canada trudeau',
#  'still engaging russia iran deal despite ukraine official',
#  'india court upholds state hijab ban schools could set national precedent',
#  'canada imposes sanctions russian officials',
#  'russian bombardment kyiv kills four curfew called',
#  'israeli forces kill two palestinians west bank violence',
#  'inside fight new abortion clinic one california city',
#  'iran foreign minister moscow hopes russian support nuclear deal isna',
#  'refugee exodus reaches million russia strikes hit west ukraine',
#  'japanese marines practise airborne assaults sign deepening cooperation',
#  'china denies claim russia asked help ukraine',
#  'raises concerns china aligning russia meeting calls intense',
#  'bermuda ban sex marriage constitutional london tribunal says',
#  'biden expected meet nato leaders brussels russia ukraine sources',
#  'consulate mexico temporarily close following gunfire gang boss arrest',
#  'warns china help russia anti war protest disrupts state tv',
#  'rare mistake prosecutors seek dismissal charges capitol riot defendant',
#  'trucker convoy seeks enter washington police block access demonstrators',
#  'prosecutors ask judge detain ex proud boys chairman tarrio',
#  'exclusive seeks expand trump era covid data collection cdc',
#  'british businessman victim execution style hit mexican tourist zone',
#  'wikileaks assange denied permission appeal extradition decision uk supreme court',
#  'iran says make decision reviving nuclear deal',
#  'reveals charges russian businessman campaign finance case',
#  'iran strike iraq signals defiance us allies region officials experts say',
#  'stocks close lower worries russia ukraine conflict',
#  'sandbags songs odessa beach ukrainians help build defences',
#  'weary refugees ukraine find shelter near auschwitz',
#  'nfl brady ends retirement says play tampa next season',
#  'south korea sees imminent prospect north icbm test newspaper',
#  'explainer legal foreigners fight ukraine',
#  'china faces consequences helps russia evade sanctions ukraine sullivan',
#  'ukraine insist talks russia presidents meeting zelenskiy',
#  'russian strike base brings ukraine war close nato border',
#  'oscar winning actor william hurt dead age deadline',
#  'iran attacks iraq erbil missiles warning allies',
#  'exclusive ukraine started using clearview ai facial recognition war',
#  'bloodied alive russian air strike western ukraine',
#  'american journalist killed ukraine kyiv region police chief says',
#  'britons get pounds month open homes ukraine refugees',
#  'long lord archbishop implores service poland ukrainians',
#  'bus carrying dozens ukrainians overturns italy one woman dead',
#  'australia vaccine diplomacy pacific islands wards beijing pm morrison',
#  'ukraine says russian forces kill seven civilians evacuation convoy',
#  'refugee arrivals dip ukraine neighbours scramble provide shelter',
#  'pakistan demands joint probe accidental india missile fire',
#  'rushing million worth weapons ukraine defense russia',
#  'ukraine trusts israeli mediation denies bennett advised caving russia',
#  'france uk germany say iran deal could collapse russian demands',
#  'turkey armenia hold constructive talks mending ties',
#  'chile new president president chileans',
#  'harris slams putin credits romania ukraine refugee help',
#  'ukraine zelenskiy defiant russian forces despite setbacks regroup near kyiv',
#  'texas judge blocks probes transgender kids parents statewide',
#  'state dept warns americans travel ukraine',
#  'north korea accused testing icbm system restoring nuclear test site',
#  'exclusive pentagon revives team speed arms ukraine allies sources',
#  'alec baldwin says contract protects liability rust shooting',
#  'allies move strip russia favored nation status sources',
#  'ghana bakers feel heat rising inflation',
#  'hope carried year old ukrainian boy fled alone slovakia says',
#  'texas top court deals blow clinics seeking block abortion law',
#  'russian strikes west ukraine aimed halting use airfields us official',
#  'russia may use chemical weapons false flag attack broadly western official says',
#  'immigration enforcement targets serious offenders overall arrests plummet',
#  'ukraine president says agreed defence sanctions support biden',
#  'volunteers pack bandages energy bars donated ukraine',
#  'ukraine envoy japan says putin may willing use nuclear weapons',
#  'two weeks ukraine war analysts detect faint glimmers compromise emerge',
#  'miss deadline release probe documents court filing shows',
#  'analysis korea satellite tech also useful manoeuvrable nuclear warheads',
#  'chile edgy barrio yungay progressive president readies move',
#  'new york first marijuana retail permits go people convictions',
#  'ukraine model taiwan defense china violate sovereignty official',
#  'russia shows reckless disregard ukraine civilians spy chiefs say',
#  'former usc water polo coach goes trial varsity blues college scandal',
#  'turkey dialogue ukraine russia important erdogan tells biden',
#  'ex canadian government official extradited face charges ransomware attacks',
#  'lev parnas ex giuliani associate plead guilty conspiracy charge',
#  'modi bjp wins big india largest state election',
#  'conservative judicial regions less apt grant inmates compassionate release commission report',
#  'putin warns west russia emerge stronger',
#  'dismisses russian claims biowarfare labs ukraine',
#  'progress ukraine ceasefire lavrov kuleba meeting',
#  'indian capital anti corruption party gets election boost take modi',
#  'north korea launch satellites monitor allies',
#  'korea elects conservative outsider president tectonic shift',
#  'thousands australians return uninhabitable homes floods recede',
#  'ukraine accuses russia genocide bombing children hospital',
#  'strict abortion limits advance idaho kentucky',
#  'iran nuclear talks stumble unresolved russian demands',
#  'million children fled ukraine since start russian invasion unicef',
#  'thousands ukrainians flee across borders many nowhere go',
#  'south korean opposition candidate yoon elected president',
#  'russia may using unguided dumb bombs ukraine war official',
#  'russia acknowledges conscripts part ukraine operation pows',
#  'bars ecuador ex president alleged corruption statement',
#  'ukraine president says fly zone needed avert humanitarian catastrophe',
#  'scant progress evacuating ukrainian civilians despite russian ceasefire promise',
#  'tunisian questionnaire constitution met nationwide shrug',
#  'taiwan says china busy party congress raise tensions',
#  'canada send ukraine another shipment military equipment trudeau says',
#  'anxious ukrainians recall last words loved ones besieged mariupol',
#  'iran says israel pay syria attack killed revolutionary guards',
#  'korea repatriates korea sailors seized boat border crossing',
#  'attacks ukrainian hospitals ambulances increasing rapidly warns',
#  'venezuela frees two americans talks',
#  'analysis taiwan studies ukraine war battle strategy china',
#  'big brands oil ban punish russia moscow makes new pledge ukraine refugees',
#  'florida lawmakers pass bill limiting lgbtq discussion school',
#  'former proud boys chairman tarrio arrested capitol riot conspiracy charge',
#  'sabotage iran deal new conditions west tells russia',
#  'watchdog homeland security office failed warn capitol threats',
#  'virginia giuffre lawsuit prince andrew dismissed britain says public funds settlement',
#  'spy chiefs say putin may escalate despite ukraine setbacks',
#  'ukraine war adds economic social setbacks women imf georgieva',
#  'maxwell juror calls failure disclose abuse huge mistake',
#  'russia ukraine still vast majority combat power intact us official',
#  'ukrainians flee besieged city sumy humanitarian corridor',
#  'canada send additional troops latvia',
#  'little time left save iran nuclear deal says',
#  'iowa reports highly pathogenic bird flu week',
#  'blinken says russia self interest preventing nuclear armed iran',
#  'nearly civilians killed afghanistan since taliban takeover un says',
#  'russia calls return peaceful co existence like cold war interfax',
#  'first convoy evacuees leaves ukrainian city sumy officials say',
#  'turkish israeli presidents meet first time fractious decade',
#  'construction spotted korea nuclear test site first time since report',
#  'ukraine zelenskiy address british parliament',
#  'gunmen kill least vigilantes nigeria kebbi state',
#  'korea could return icbm nuclear tests year intelligence report',
#  'russia warns oil import ban little progress made ukraine talks',
#  'venezuela maduro says work agenda agreed delegation',
#  'minneapolis school teachers call strike classes canceled',
#  'russia offers humanitarian corridors five ukraine cities reports',
#  'latvian woman drives ukraine rescue pets',
#  'guantanamo detainee called th hijacker repatriated saudi arabia',
#  'teenager dead two critical condition shooting outside iowa high school police',
#  'naming shaming russia part pope diplomatic playbook experts say',
#  'iran envoy leaves eu says time decide nuclear talks',
#  'allies urge russia allow safe passage civilians aid ukraine',
#  'foreign fighters ukraine offers purpose camaraderie cause',
#  'supreme court nixes bid reinstate bill cosby conviction',
#  'biden allies affirm call continue raising costs russia ukraine invasion',
#  'says least nine killed attacks ukraine health care',
#  'adopts rules easing path green cards abused neglected minors',
#  'florida panhandle wildfires force evacuation hundreds homes',
#  'ukraine president seeks international trade embargo russia',
#  'seeks calm fears baltics putin stop ukraine',
#  'canada impose sanctions individuals close russia putin says trudeau',
#  'russian show court hearing ukrainian genocide',
#  'queen meets canadian pm first person meeting since catching covid',
#  'iran says russian demand nuclear talks constructive report',
#  'ukraine prods israel aid grateful moscow mediation bid',
#  'climate change covid loom alaska th annual iditarod sled dog race',
#  'ukrainian forces retake control northeastern town ukrainian official say',
#  'western nations plan sanctions russia canada foreign minister',
#  'blinken says sacrosanct commitment nato article',
#  'russian police detained people sunday anti war protests monitor',
#  'thailand bids avert population crisis birth rate crashes',
#  'detained anti war protests russia',
#  'explainer north korea satellite launches controversial',
#  'philippine leader approves bill raising sex consent age',
#  'residents fleeing town near kyiv caught shelling',
#  'israeli attack damascus kills two syrian state media',
#  'korea ruling party leader hospitalised attack rally yonhap',
#  'fighting traps residents mariupol putin calls ukraine surrender',
#  'people convoy truck protest targets washington slows traffic',
#  'young residents ukrainian orphanage flee safety',
#  'working secure release basketball star detained russia',
#  'bennett says israel try mediate ukraine even prospects poor',
#  'iranian nuclear talks clouded russian demands',
#  'sees credible reports deliberate attacks civilians ukraine',
#  'top diplomat blinken reassures moldova amid refugee influx ukraine',
#  'russia without evidence says ukraine making nuclear dirty bomb',
#  'officials travel venezuela russian ally talks source',
#  'trucks rvs cars flock washington area protest covid restrictions',
#  'tornado slams central iowa killing least six',
#  'new york little odessa ukrainians see russians neighbors enemies',
#  'putin likens western sanctions war russian assault traps ukrainian civilians',
#  'canada tells citizens leave russia due unpredictable security situation',
#  'north korea says conducted second important spy satellite test',
#  'russia demand us guarantees may hit nuclear talks iran official says',
#  'blinken signals support ukraine border meeting',
#  'wnba star griner detained russia customs service cites hash possession',
#  'putin says western sanctions akin declaration war',
#  'russia protests envoy senator call take putin',
#  'evacuation trains war zone pour lviv western ukraine',
#  'please close sky say ukrainian refugees',
#  'civilians confirmed killed ukraine far says',
#  'new ambassador nicholas burns arrives china',
#  'china pledges peaceful growth taiwan ties opposes foreign interference',
#  'china announces south china sea drills close vietnam coast',
#  'least killed suicide bombing shi ite mosque pakistan',
#  'russian law fake news prompts media halt reporting websites blocked',
#  'embassy ukraine calls nuclear power plant attack war crime',
#  'court allows biden mexico border expulsions limits',
#  'nato rejects ukraine fly zone unhappy zelenskiy says means bombing',
#  'russians ukrainians seek asylum mexico border',
#  'supreme court restores boston marathon bomber death sentence',
#  'ukraine russia need know right',
#  'calls help rehome afghans fled chaos taliban takeover',
#  'putin says russia neighbours escalate tensions',
#  'recognise taiwan former top diplomat pompeo says',
#  'supreme court rules fbi muslim surveillance dispute',
#  'icc faces myriad challenges prosecute war crimes ukraine',
#  'berlin main train station becomes ukrainian refugee welcome center',
#  'separatists indonesia papua kill workers telecom tower',
#  'russian seizure ukraine nuclear plant sparks worries radiation monitoring',
#  'nod climate change alaska iditarod marks th running',
#  'seek conflict russia ready says',
#  'korea next president face korea forging ahead nuclear missile production',
#  'florida senate passes week abortion ban sends governor',
#  'jury acquits louisville officer charged breonna taylor raid',
#  'yacht seized ramps oligarch sanctions putin feels squeeze',
#  'ukraine russia agree evacuation corridors punishes oligarchs',
#  'secret service takes two men custody washington georgetown neighborhood',
#  'texas appeals order stopping investigating parents transgender teen',
#  'iran nuclear talks appear near climax deal yet',
#  'fire building collapse injures nearly dozen maryland',
#  'supreme court nixes cia contractors testimony guantanamo detainee',
#  'iaea chief visit iran possible boost nuclear deal',
#  'veteran prosecutor lead task force probing russian oligarchs',
#  'eu backs move give ukraine refugees temporary residency',
#  'ottawa police misjudged protesters besieged canada capital testimony',
#  'two cargo ships hit blasts around ukraine one seafarer killed',
#  'iran nearing nuclear bomb yardstick enriched uranium stock grows',
#  'civilian casualties rise ukraine dead injured un',
#  'taiwan honours former top diplomat pompeo china calls despicable',
#  'germany wants inquiry russian human rights violations ukraine',
#  'general assembly historic vote denounces russia ukraine invasion',
#  'ukraine second city heavily bombed assembly denounces russia',
#  'prosecutors seek immunity ghislaine maxwell juror disclose abuse',
#  'born war kyiv maternity hospital carries siege',
#  'delays icbm test launch bid de escalate russia nuclear tensions',
#  'russia space agency head says satellite hacking would justify war report',
#  'results key races texas primary elections',
#  'anger disbelief amidst rubble ukraine kharkiv',
#  'republican abbott democrat rourke face texas governor race primary wins',
#  'factbox chain command potential russian nuclear strikes',
#  'launches kleptocapture task force aimed russian oligarchs',
#  'russia aims erase us ukraine zelenskiy says day war',
#  'sandbags soldiers ukraine leader gives interview siege',
#  'kyiv residents staying put say ready fight die',
#  'arab refugees see double standards europe embrace ukrainians',
#  'russia steps assault fleeing fear fathers left behind',
#  'dramatic call ukraine leader prompted historic eu move provide arms',
#  'russian ukrainian couple make five day escape hungary kyiv',
#  'former top diplomat pompeo arrives taiwan calls great nation',
#  'australia evacuates tens thousands heavy rains threaten sydney',
#  'russia bombards ukraine urban areas armed convoy stalls',
#  'factbox key federal state races watch tuesday texas primary',
#  'canada refer icc probe alleged russian war crimes ukraine',
#  'emerging darkness mardi gras revelers shed pandemic woes',
#  'hundreds arrested globally new zealand led online child abuse investigation',
#  'ukraine crisis emerges talking point gun debate',
#  'exclusive ukraine zelenskiy tells russia stop bombing ceasefire talks',
#  'sport russian belarusian athletes banned tennis players avoid tour exclusion',
#  'analysis russian ransomware attacks ukraine muted leaks insurance woes',
#  'former comic actor zelenskiy unlikely war leader ukraine',
#  'smartphone hand ukraine president takes centre stage capital attack',
#  'supreme court mulls pill mill doctors opioid convictions',
#  'blinken says russian crimes mounting hour ukraine',
#  'indian student killed ukraine shelling thousands foreigners trapped',
#  'ukraine kharkiv struck cluster bombs experts say',
#  'airbnb house ukrainian refugees',
#  'ukraine zelenskiy tells eu prove us',
#  'protect sky ukrainian activist emotional plea uk johnson',
#  'analysis pays un climate report reignites global fight compensation',
#  'ukrainians face long journeys borders fighting escalates',
#  'uk relaxes visa rules ukrainian refugees johnson warns millions could flee',
#  'western envoys allies walk lavrov speech un rights forum',
#  'russian billionaire fridman contest groundless eu sanctions',
#  'analysis foes ukraine russia western unity tested iran talks',
#  'refugees pour defiant ukrainian city prepares war',
#  'least killed latest rocket strikes ukraine kharkiv says ukrainian official',
#  'reports least civilian casualties ukraine',
#  'ukraine seeks disarmament meeting russia invasion weapons mass destruction',
#  'red cross seeks funds ukraine aid access detainees',
#  'people flee ukraine un agency says',
#  'delegation arrives taiwan china denounces visit',
#  'tiktok war russia invasion ukraine played social media youngest audience',
#  'olympics ioc recommends banning russian belarusian athletes international events',
#  'ukraine calls fly zone stop russian bombardment',
#  'general assembly set isolate russia ukraine invasion',
#  'americans canadians answer ukraine call foreign fighters',
#  'exclusive set announce increased staffing havana embassy process visas sources',
#  'rocket strikes kill ukrainian city kharkiv says regional official',
#  'iran says key issues still unresolved nuclear talks',
#  'young ukrainian fled kyiv returns join war',
#  'biden says americans worry nuclear war russian actions',
#  'california oregon washington end school mask mandates march',
#  'russian muscle movements putin nuclear readiness alert says',
#  'expels russian diplomats security concerns',
#  'shuts embassy belarus oks evacuation embassy moscow',
#  'sport sporting bodies move ban russian athletes amid invasion ukraine',
#  'erdogan says turkey cannot abandon ties russia ukraine',
#  'ukraine war risks economy hinge conflict length white house adviser',
#  'german revellers swap carnival parade anti war rally',
#  'freezing weather border bottlenecks ukrainians flee war',
#  'fifa uefa suspend russia competitions notice',
#  'first criminal trial accused capitol rioter begins jury selection',
#  'delay means death un climate report urges immediate drastic action',
#  'ukraine seeks un investigation alleged russia war crimes',
#  'eu says refugees ukraine far millions expected',
#  'mothers babies shelter basement children hospital kyiv',
#  'ukrainian president signs formal request join european union',
#  'sees reason change nuclear alert levels time white house',
#  'north korea blames ukraine crisis hegemonic high handedness',
#  'handful russian media websites display anti putin message hack',
#  'supreme court takes dispute native american adoption law',
#  ...]

# %%
clean_news[0].split()
# Out:
# ['envoy', 'seoul', 'talks', 'north', 'korea', 'missile', 'nuclear', 'tensions']

# %%
news['clean_news']= clean_news

# %%
news
# Out:
#          company                                               date  \
# 0     By Reuters  <span>2 minutes ago (Apr 17, 2022 09:25PM ET)<...
# 1     By Reuters  <span>9 minutes ago (Apr 17, 2022 09:18PM ET)<...
# 2     By Reuters  <span>37 minutes ago (Apr 17, 2022 08:50PM ET)...
# 3     By Reuters  <span>1 hour ago (Apr 17, 2022 08:21PM ET)</span>
# 4     By Reuters  <span>1 hour ago (Apr 17, 2022 08:05PM ET)</span>
# ...          ...                                                ...
# 1713  By Reuters               <span>Jan 25, 2022 02:06AM ET</span>
# 1714  By Reuters               <span>Jan 25, 2022 12:42AM ET</span>
# 1715  By Reuters               <span>Jan 25, 2022 12:27AM ET</span>
# 1716  By Reuters               <span>Jan 24, 2022 11:05PM ET</span>
# 1717  By Reuters               <span>Jan 24, 2022 10:30PM ET</span>
#
#                                                   title  \
# 0     U.S. envoy in Seoul for talks over North Korea...
# 1     Ukrainians defy Russian surrender demand in Ma...
# 2     Police hunt for Pittsburgh party shooters who ...
# 3     Ukraine completes questionnaire for EU members...
# 4     Brazil arrests 'Colorido,' PCC drug gang's No....
# ...                                                 ...
# 1713  U.S. orders departure of Ukraine embassy staff...
# 1714  Burkina Faso army deposes president in West Af...
# 1715  NASA's new space telescope reaches destination...
# 1716  Tennis-'Where is Peng Shuai?' shirts welcome a...
# 1717  New York City Mayor Adams unveils plan to end ...
#
#                                                 content  \
# 0     By Josh Smith\nSEOUL (Reuters) - The U.S. envo...
# 1     By Oleksandr Kozhukhar and Alessandra Prentice...
# 2     (Reuters) - Police were searching for the shoo...
# 3     (Reuters) - Ukraine has completed a questionna...
# 4     RIO DE JANEIRO (Reuters) - Brazil's justice mi...
# ...                                                 ...
# 1713  By David Shepardson and Costas Pitas\nWASHINGT...
# 1714  By Thiam Ndiaga\nOUAGADOUGOU (Reuters) - Burki...
# 1715  By Steve Gorman\n(Reuters) -NASA's James Webb ...
# 1716  By Sudipto Ganguly\nMELBOURNE (Reuters) - Fans...
# 1717  By Barbara Goldberg and Julia Harte\nNEW YORK ...
#
#                                              clean_news
# 0     envoy seoul talks north korea missile nuclear ...
# 1     ukrainians defy russian surrender demand mariu...
# 2     police hunt pittsburgh party shooters killed i...
# 3     ukraine completes questionnaire eu membership ...
# 4          brazil arrests colorido pcc drug gang leader
# ...                                                 ...
# 1713  orders departure ukraine embassy staff family ...
# 1714  burkina faso army deposes president west afric...
# 1715  nasa new space telescope reaches destination s...
# 1716   tennis peng shuai shirts welcome australian open
# 1717  new york city mayor adams unveils plan end gun...
#
# [1718 rows x 5 columns]

# %%
# 단어로 나눠서 리스트에 담기 
news['clean_news'] = news['clean_news'].apply(lambda x : x.split())
news['clean_news'] = news['clean_news'].apply(lambda x: x+' ')
# Out:
# 0       [envoy, seoul, talks, north, korea, missile, n...
# 1       [ukrainians, defy, russian, surrender, demand,...
# 2       [police, hunt, pittsburgh, party, shooters, ki...
# 3       [ukraine, completes, questionnaire, eu, member...
# 4       [brazil, arrests, colorido, pcc, drug, gang, l...
#                               ...
# 1713    [orders, departure, ukraine, embassy, staff, f...
# 1714    [burkina, faso, army, deposes, president, west...
# 1715    [nasa, new, space, telescope, reaches, destina...
# 1716    [tennis, peng, shuai, shirts, welcome, austral...
# 1717    [new, york, city, mayor, adams, unveils, plan,...
# Name: clean_news, Length: 1718, dtype: object

# %%
# 날짜 합치고 중복제거 
# 함수 적용  
import re
news['date'] = news['date'].astype(str).str.strip('<span>').str.strip('</span>')
news['date'] = news['date'].str.replace('\n','').str.replace('—','')
news['date'] = news['date'].apply(lambda x: re.findall('\(([^)]+)',x)[0] if re.findall('\(([^)]+)',x) else x )
news['date'] = pd.to_datetime(news['date'].astype(str),utc=True).astype(str).apply(lambda x: x[:10]).astype('datetime64')
# Out:
# C:\Users\bitcamp\anaconda3\envs\cuda\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)

# %%
# news.set_index(news['date'],inplace=True)

# %%
news
# Out:
#          company       date  \
# 0     By Reuters 2022-04-17
# 1     By Reuters 2022-04-17
# 2     By Reuters 2022-04-17
# 3     By Reuters 2022-04-17
# 4     By Reuters 2022-04-17
# ...          ...        ...
# 1713  By Reuters 2022-01-25
# 1714  By Reuters 2022-01-25
# 1715  By Reuters 2022-01-25
# 1716  By Reuters 2022-01-24
# 1717  By Reuters 2022-01-24
#
#                                                   title  \
# 0     U.S. envoy in Seoul for talks over North Korea...
# 1     Ukrainians defy Russian surrender demand in Ma...
# 2     Police hunt for Pittsburgh party shooters who ...
# 3     Ukraine completes questionnaire for EU members...
# 4     Brazil arrests 'Colorido,' PCC drug gang's No....
# ...                                                 ...
# 1713  U.S. orders departure of Ukraine embassy staff...
# 1714  Burkina Faso army deposes president in West Af...
# 1715  NASA's new space telescope reaches destination...
# 1716  Tennis-'Where is Peng Shuai?' shirts welcome a...
# 1717  New York City Mayor Adams unveils plan to end ...
#
#                                                 content  \
# 0     By Josh Smith\nSEOUL (Reuters) - The U.S. envo...
# 1     By Oleksandr Kozhukhar and Alessandra Prentice...
# 2     (Reuters) - Police were searching for the shoo...
# 3     (Reuters) - Ukraine has completed a questionna...
# 4     RIO DE JANEIRO (Reuters) - Brazil's justice mi...
# ...                                                 ...
# 1713  By David Shepardson and Costas Pitas\nWASHINGT...
# 1714  By Thiam Ndiaga\nOUAGADOUGOU (Reuters) - Burki...
# 1715  By Steve Gorman\n(Reuters) -NASA's James Webb ...
# 1716  By Sudipto Ganguly\nMELBOURNE (Reuters) - Fans...
# 1717  By Barbara Goldberg and Julia Harte\nNEW YORK ...
#
#                                              clean_news
# 0     envoy seoul talks north korea missile nuclear ...
# 1     ukrainians defy russian surrender demand mariu...
# 2     police hunt pittsburgh party shooters killed i...
# 3     ukraine completes questionnaire eu membership ...
# 4          brazil arrests colorido pcc drug gang leader
# ...                                                 ...
# 1713  orders departure ukraine embassy staff family ...
# 1714  burkina faso army deposes president west afric...
# 1715  nasa new space telescope reaches destination s...
# 1716   tennis peng shuai shirts welcome australian open
# 1717  new york city mayor adams unveils plan end gun...
#
# [1718 rows x 5 columns]

# %%
news.groupby('date')['clean_news'].sum()[1]
# Out:
# 'debt dispute probably sparked killing two canadians mexico indonesia singapore sign extradition airspace defence agreements supreme court hear challenge race conscious college admissions new mexico national guard members teach covid hit schools drugmaker teva fueled opioid addiction new york jury finds thich nhat hanh poetic peace activist master mindfulness dies top senate republican says biden moving right direction ukraine korea fires cruise missiles amid tension lifting nuclear moratorium finland enhances military readiness tension rises ukraine kremlin says watching actions ukraine great concern australia buys copyright aboriginal flag making free fly stadium stampede kills eight africa cup nations soccer match royal crown slips elizabeth prepares mark years queen russia adds putin critic navalny list terrorists extremists japan doubles areas covid curbs cases set records cambodia pm says myanmar junta welcome asean progress made explainer wall ice fukushima crippled nuclear plant assume covid pandemic reaching end game warns orders departure ukraine embassy staff family members burkina faso army deposes president west africa latest coup nasa new space telescope reaches destination solar orbit '

# %%
# 빈도수 추출
